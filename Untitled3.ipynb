# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitnayan12/face_recognition-Arc-Face-Additive-Angular-Margin-Loss/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**1) Introduction**
#
# This is a tensorflow implementation of paper "***ArcFace: Additive Angular Margin Loss for Deep Face Recognition***".
# Additive Angular Margin Loss (ArcFace) is used to obtain highly discriminative features for face recognition. The proposed ArcFace has a clear geometric interpretation due to the exact correspondence to the geodesic distance on the hypersphere. This implementation aims at making both usage of pretrained model and training of your own model easier. Whether you just want to use pretrained model to do face recognition/verification or you want train/finetune your own model.
#
# https://github.com/luckycallor/InsightFace-tensorflow

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=16T9P7FMoK_1erij9Ur14eoJkFIlqpPJl)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/InsightFace-tensorflow-masternew/data')

# %%
pip install scipy==1.1.0

# %% [markdown]
# ##**2)  Train your own model from scratch,  with your own data**
#
# Generating tfr records to train model using own data

# %%
# %run generateTFRecord.py --mode=folders --image_size=112 --read_dir=read_dir --save_path=tfr.tfrecord
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# write tfrecord from folders...
# WARNING:tensorflow:From /content/drive/My Drive/InsightFace-tensorflow-masternew/data/classificationDataTool.py:80: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# done![100/100]
# class num: 10

# %%
tf.reset_default_graph()

# %%
cd /content/drive/My Drive/Colab Notebooks/InsightFace-tensorflow-masternew
# Out:
# /content/drive/My Drive/Colab Notebooks/InsightFace-tensorflow-masternew

# %% [markdown]
# **Train with Softmax**

# %%
# %run train_softmax.py --config_path=configs/config_ms1m_100.yaml
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %% [markdown]
# ##**3)  Model Evaluation**
#
# We will now use a pre-trained model(**backbone_type: resnet_v2_m_50**). As training from scratch is very expensive and requires huge datasets to achieve good generalization performance.
# The accuracy of **additive angular margin loss (arc face loss)** is calculated on **AGE_DB30 dataset, LFW** , CFP_FF, CFP_FP dtaset is calculated

# %%
# %run evaluate.py --config_path=configs/config_ms1m_100.yaml --model_path=config_ms1m_100_1006k/best-m-1006000
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %% [markdown]
# ##**4) Result**

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1mvcjr8j2Ej9T4UaZjQ3AaFzfVT-fq16g)

# %%
tf.reset_default_graph()

# %% [markdown]
# ##**5)  Extract Embedding with Pretrained** **Model**
#
# Here we extract embedding from face images with get_embd.py  script.
#
# where **config_path** and model_path specify the config file and pretrained model respectively. read_path is path to face images, that can be a path to one image or a directory with only images in it. save_path specifies where to save the embedding. The saved file is a dict with image file name as key, the corresponding embedding as value, and can be loaded with pickle in python

# %%
# %run get_embd.py --config_path=configs/config_ms1m_100.yaml --model_path=config_ms1m_100_1006k/best-m-1006000 --read_path=IMG/Face_images/Ariel_Sharon_0001.jpg --save_path=embd.pkl
# Out:
# building...
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# done!
# loading...
# done!
# reading IMG/Face_images/Ariel_Sharon_0001.jpg
# done!
# forward running...
# /content/drive/My Drive/Colab Notebooks/InsightFace-tensorflow-masternew/get_embd.py:37: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = misc.imread(path)
# /content/drive/My Drive/Colab Notebooks/InsightFace-tensorflow-masternew/get_embd.py:38: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   img = misc.imresize(img, [image_size, image_size])
# done!
#
# done!
# done!
# saving...
# ['Ariel_Sharon_0001.jpg']
# [[-2.02730522e-02 -2.50172266e-03  7.00937659e-02 -9.39547643e-03
# ...
